# %%
import numpy as np

# %%
def sample_p_b():
    np.random.choice(['T', 'F'], p=[0.001, 0.999])

# %%
def sample_p_e():
    np.random.choice(['T', 'F'], p=[0.002, 0.998])

# %%
B_sample = sample_p_b()
E_sample = sample_p_e()
# these two values are either true or false, random each time

# %%
def sample_p_a(b, e):
    if b=='T' and e=='T':
        a = np.random.choice(['T', 'F'], p=[0.95, 0.05])
    elif b=='T' and e=='F':
        a = np.random.choice(['T', 'F'], p=[0.94, 0.06])
    elif b=='F' and e=='T':
        a = np.random.choice(['T', 'F'], p=[0.29, 0.71])
    elif b=="F" and e=="F":
        a= np.random.choice(['T', 'F'], p=[0.001,0.999]) 
    A_sample = sample_p_a(b=B_sample, e=E_sample)
    return a
    print(a)

# %%
def sample_p_j(a):
    if a=='T':
        j = np.random.choice(['T', 'F'], p=[0.9, 0.1])
    elif a=='F':
        j =np.random.choice(['T', 'F'], p=[0.05, 0.95])

# %%
def sample_p_m(a):
    if a=='T':
        m =np.random.choice(['T','F'], P=[0.70,0.30])
    elif a=='F':
      m=np.random.choice(['T','F'], p=[0.01,0.99])

# %%
def sample_p_ejm(a,b):
  if a=='T'and b=='T' :
    x = np.random.choice(['T','F'], p=[0.0000007093,0.9999992907])
  elif a=='T' and b=='F':
    x = np.random.choice(['T','F'], p=[0.000000001, 0.999999999])
  elif a=='F' and b=='T':
    x=np.random.choice(['T','F'], p=[0.0003650346, 0.9996349654])
  elif a=='F' and b=='F':
    x=np.random.choice(['T','F'], p=[0.0000011970, 0.999998803])
  EJM_sample = sample_p_ejm(a=A_sample, b=B_sample)
  return x

# %%
from numpy.random.mtrand import choice
def sample_p_jm(a,b,e):
  if a=='T' and b=='T' and e=='T':
    y = np.random.choice(['T','F'],p=[0.0004980, 0.999502])
  elif a=='T' and b=='T' and e=='F':
    y=np.random.choice(['T','F'], p=[0.0000007, 0.9999993])
  elif a=='T' and b=='F' and e=='T':
    y=np.random.choice(['T','F'],p[0.0000002, 0.9999998])
  elif a=='T' and b=='F' and e=='F':
    y=np.random.choice(['T','F'],p[0,1])
  elif a=='F' and b=='T' and e=='T':
    y=np.random.choice(['T','F'],p[0.0006281, 0.9993719])
  elif a=='F' and b=='T' and e=='F':
    y=np.random.choice(['T','F'],p[0.0003650, 0.9996350])
  elif a=='F' and b=='F' and e=='T':
    y=np.random.choice(['T','F'],p[0.0005910, 0.999409])
  elif a=='F' and b=='F' and e=='F':
    y=np.random.choice(['T','F'],p[0.00000119, 0.99999881])

  JM_sample = sample_p_jm(a=A_sample, b=B_sample, e=E_sample)
  return y
